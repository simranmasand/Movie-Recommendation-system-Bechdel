# %%
import numpy as np
import pandas as pd

# %%
credits=pd.read_csv('credits.csv')
links=pd.read_csv('links.csv',dtype={'imdbId':object})
movie_metadata=pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\isimr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
new_df=pd.merge(links,credits,left_on='movieId',right_on='id')
print(new_df.shape)
new_df.head()
# Out:
# (7641, 6)
#    movieId   imdbId   tmdbId  \
# 0        2  0113497   8844.0
# 1        3  0113228  15602.0
# 2        5  0113041  11862.0
# 3        6  0113277    949.0
# 4       11  0112346   9087.0
#
#                                                 cast  \
# 0  [{'cast_id': 3, 'character': 'Taisto Olavi Kas...
# 1  [{'cast_id': 5, 'character': 'Nikander', 'cred...
# 2  [{'cast_id': 42, 'character': 'Ted the Bellhop...
# 3  [{'cast_id': 7, 'character': 'Frank Wyatt', 'c...
# 4  [{'cast_id': 3, 'character': 'Luke Skywalker',...
#
#                                                 crew  id
# 0  [{'credit_id': '52fe420dc3a36847f800001f', 'de...   2
# 1  [{'credit_id': '52fe420dc3a36847f8000077', 'de...   3
# 2  [{'credit_id': '52fe420dc3a36847f800011b', 'de...   5
# 3  [{'credit_id': '52fe420dc3a36847f800023d', 'de...   6
# 4  [{'credit_id': '52fe420dc3a36847f8000437', 'de...  11

# %%
new_df.to_csv('more_data.csv')

# %%
new_df
# Out:
#       movieId   imdbId    tmdbId  \
# 0           2  0113497    8844.0
# 1           3  0113228   15602.0
# 2           5  0113041   11862.0
# 3           6  0113277     949.0
# 4          11  0112346    9087.0
# ...       ...      ...       ...
# 7636   176077  2400314  264269.0
# 7637   176085  5735280  434873.0
# 7638   176143  2147597   98604.0
# 7639   176167  0071450  258907.0
# 7640   176273  0303758   67758.0
#
#                                                    cast  \
# 0     [{'cast_id': 3, 'character': 'Taisto Olavi Kas...
# 1     [{'cast_id': 5, 'character': 'Nikander', 'cred...
# 2     [{'cast_id': 42, 'character': 'Ted the Bellhop...
# 3     [{'cast_id': 7, 'character': 'Frank Wyatt', 'c...
# 4     [{'cast_id': 3, 'character': 'Luke Skywalker',...
# ...                                                 ...
# 7636  [{'cast_id': 4, 'character': 'Jim Whitman', 'c...
# 7637  [{'cast_id': 3, 'character': 'Suzanne Barringt...
# ...
